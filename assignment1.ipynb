# %% [markdown]
# ## Assignment 1
# - Use the iris dataset from sklearn to perform some data manipulation or visualization. Think about how these packages and models can be utilized outside of this dataset in your everyday lives. Each student must use 2 of the 4 following packages to manipulate the data (loading the iris dataset does not count).
#
# - Possible Packages:
#     - Numpy
#     - Pandas
#     - Sklearn
#     - Matplotlib or Seaborn

# %%
# importing libraries
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sk
import seaborn as sns

# %%
from sklearn.datasets import load_iris

iris = load_iris()  # loading the iris dataset

data = pd.DataFrame(iris.data, columns=iris.feature_names)

data['class'] = iris.target_names[iris.target]

print(data)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#          class
# 0       setosa
# ...

# %%
# find the number of each class in the dataset
print(data['class'].value_counts())


nice_data = pd.DataFrame(data, columns=['class', 'sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)'])

display(nice_data)

# find average of sepal length

print ("Average of sepal length : ", nice_data['sepal length (cm)'].mean(), "cm")

# find average of sepal width

print ("Average of sepal width : ", nice_data['sepal width (cm)'].mean(), "cm") 

# find average of petal length

print ("Average of petal length : ", nice_data['petal length (cm)'].mean(), "cm")

# find average of petal width

print ("Average of petal width : ", nice_data['petal width (cm)'].mean(), "cm")
# Out:
# class
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64
#          class  sepal length (cm)  sepal width (cm)  petal length (cm)  \
# 0       setosa                5.1               3.5                1.4
# 1       setosa                4.9               3.0                1.4
# 2       setosa                4.7               3.2                1.3
# 3       setosa                4.6               3.1                1.5
# 4       setosa                5.0               3.6                1.4
# ..         ...                ...               ...                ...
# 145  virginica                6.7               3.0                5.2
# 146  virginica                6.3               2.5                5.0
# 147  virginica                6.5               3.0                5.2
# 148  virginica                6.2               3.4                5.4
# 149  virginica                5.9               3.0                5.1
#
#      petal width (cm)
# ...

# %%
# create a pie chart with seaborn / matplotlib

data_class = data['class'].value_counts()
keys = data['class'].value_counts().keys()

# declaring exploding pie 
explode = [0, 0.1, 0] 
# define Seaborn color palette to use 
palette_color = sns.color_palette('deep') 
  
# plotting data on chart 
plt.pie(data_class, labels=keys, colors=palette_color, 
        explode=explode, autopct='%.0f%%') 
  
# displaying chart 
plt.show()
